# %% [markdown]
# # 02 — Preprocessing
# Normalize text, report missingness and conflicts, and deduplicate before splitting.

# %%
import sys
sys.path.append('../src')
from preprocess import preprocess_dataframe
clean, quality = preprocess_dataframe(data)
print(quality)
display(clean[['statement','clean_text','status','word_count']].head())
