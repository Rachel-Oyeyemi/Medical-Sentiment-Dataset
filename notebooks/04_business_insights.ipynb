# %% [markdown]
# # 04 — Business and Responsible-AI Insights
# Translate model performance into bounded, human-reviewed use cases.

# %%
from sklearn.metrics import classification_report
for name, model in [('Baseline', baseline), ('Advanced', advanced)]:
    prediction = model.predict(test[TEXT_FEATURE])
    print(name)
    print(classification_report(test[TARGET], prediction, zero_division=0))
print('Do not use these dataset labels as diagnoses or autonomous crisis decisions.')
