# %% [markdown]
# # 03 — Modeling
# Compare word TF-IDF Logistic Regression with a calibrated word/character Linear SVM.

# %%
import sys
sys.path.append('../src')
from train_model import split_data, build_baseline, build_advanced
from feature_engineering import TEXT_FEATURE, TARGET
train, validation, test = split_data(clean)
baseline = build_baseline().fit(train[TEXT_FEATURE], train[TARGET])
advanced = build_advanced().fit(train[TEXT_FEATURE], train[TARGET])
print(len(train), len(validation), len(test))
